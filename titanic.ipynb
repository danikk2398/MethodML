# %%
import numpy as np
import pandas as pd
import statistics as stat
# %matplotlib inline

# %%
data = pd.read_csv('data/titanic.csv')

# %%
data.head(7)
# Out:
#    832  1  2 Richards, Master. George Sibley    male  0.83  1.1  1.2  \
# 0  833  0  3                  Saad, Mr. Amin    male   NaN    0    0
# 1  834  0  3          Augustsson, Mr. Albert    male  23.0    0    0
# 2  835  0  3          Allum, Mr. Owen George    male  18.0    0    0
# 3  836  1  1     Compton, Miss. Sara Rebecca  female  39.0    1    1
# 4  837  0  3                Pasic, Mr. Jakob    male  21.0    0    0
# 5  838  0  3             Sirota, Mr. Maurice    male   NaN    0    0
# 6  839  1  3                 Chip, Mr. Chang    male  32.0    0    0
#
#       29106    18.75 Unnamed: 10  S
# 0      2671   7.2292         NaN  C
# 1    347468   7.8542         NaN  S
# 2      2223   8.3000         NaN  S
# 3  PC 17756  83.1583         E49  C
# 4    315097   8.6625         NaN  S
# 5    392092   8.0500         NaN  S
# 6      1601  56.4958         NaN  S

# %%
data.describe()
# Out:
#               832          1          2       0.83        1.1        1.2  \
# count   59.000000  59.000000  59.000000  49.000000  59.000000  59.000000
# mean   862.000000   0.355932   2.338983  29.500000   0.559322   0.440678
# std     17.175564   0.482905   0.843028  13.520817   1.556645   0.914843
# min    833.000000   0.000000   1.000000   4.000000   0.000000   0.000000
# 25%    847.500000   0.000000   2.000000  20.000000   0.000000   0.000000
# 50%    862.000000   0.000000   3.000000  27.000000   0.000000   0.000000
# 75%    876.500000   1.000000   3.000000  39.000000   0.500000   1.000000
# max    891.000000   1.000000   3.000000  74.000000   8.000000   5.000000
#
#             18.75
# count   59.000000
# mean    24.912849
# std     28.190073
# min      5.000000
# 25%      7.910400
# 50%     13.000000
# 75%     29.850000
# max    164.866700

# %%
data[(data.Embarked=='C')&(data.Fare>200)].head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-c0173a8ecd2b> in <module>
# ----> 1 data[(data.Embarked=='C')&(data.Fare>200)].head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Embarked'

# %%
len(data[data.Sex=='male'])
# Out:
# 577

# %%
len(data[data.Sex!='male'])
# Out:
# 314

# %%
len(data[(data.Pclass==2)&(data.Sex=='male')])
# Out:
# 108

# %%
data.Fare.median(), data.Fare.std()
# Out:
# (14.4542, 49.693428597180905)

# %%
o=len(data[(data.Survived==1)&(data.Age>30)])
y=len(data[(data.Survived==1)&(data.Age<30)])
if(y<o):
    print("Ложь",o/len(data[(data.Age>30)])*100,y/len(data[(data.Age<30)])*100)
else:
    print("Правда",o/len(data[(data.Age>30)])*100,y/len(data[(data.Age<30)])*100)
# Out:
# Правда 40.65573770491803 40.625

# %%
len(data[(data.Sex=='female')&(data.Survived==1)]),\
(len(data[(data.Sex=='female')&(data.Survived==1)])/len(data[(data.Sex=='female')]))
# Out:
# (233, 0.7420382165605095)

# %%
len(data[(data.Sex=='male')&(data.Survived==1)]),\
(len(data[(data.Sex=='male')&(data.Survived==1)])/len(data[(data.Sex=='male')]))
# Out:
# (109, 0.18890814558058924)

# %%
arr=[]
for index,row in data.iterrows():
    if(row.Sex=='male'):
        name=row['Name'].split()
        arr.append(name[2])
print(stat.mode(arr))
# Out:
# William

# %%
data[data.Survived==1].Fare.mean(),data[data.Survived==0].Fare.mean()
# Out:
# (48.39540760233917, 22.117886885245877)

# %%
s=data[data.Survived==1].Age.mean()
d=data[data.Survived==0].Age.mean()
if(s>d):
    print("Ложь")
else:
    print("Правда")
# Out:
# Правда

# %%
data[data.Sex!='male'].pclas
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 15                  0       3
# 16                  1       2
# 19                  0       3
# 20                  1       3
# 23                  1       3
# 25                  0       3
# 26                  1       3
# 29                  1       3
# 32                  1       1
# 33                  1       3
# 39                  0       3
# 40                  1       3
# 41                  0       3
# 42                  0       2
# 44                  1       2
# 45                  1       3
# 48                  1       3
# 50                  0       3
# 53                  1       1
# 54                  1       2
# 57                  1       2
# 59                  1       2
# ...
